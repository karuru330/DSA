# %% [markdown]
# ## Permutations and Combinations

# %% [markdown]
# Permutation - It is an arrangement of r things that can be done out n things
#
# nPr = (n!)/(n-r)!
#
# Combination - It is selection of r things that can be done out of n things
#
# nCr = (n!)/((r!)*(n-r)!)
